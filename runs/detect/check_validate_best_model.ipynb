# %% [markdown]
# 查看某次實驗的最佳模型的各種指標(例如mAP50等)(用驗證資料驗證)

# %%
from ultralytics import YOLO

# 1️⃣ 載入那次實驗的 best.pt
model = YOLO('/NFS/celine/aicup/yoloNew/runs/detect/heart_valve_detector_nano1012/weights/best.pt')
# 2️⃣ 驗證這個模型
#results = model.val(data='data.yaml')  # 用同樣的 data.yaml
results = model.val(data='/NFS/celine/aicup/yoloNew/data.yaml')

# 3️⃣ 印出關鍵結果
print(results.results_dict['metrics/mAP50(B)'])
print(results.results_dict['metrics/mAP50-95(B)'])
# Out:
# Ultralytics 8.3.218 🚀 Python-3.10.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3090, 24257MiB)
# YOLOv12s summary (fused): 159 layers, 9,231,267 parameters, 0 gradients, 21.2 GFLOPs
# WARNING ⚠️ val: Slow image access detected (ping: 14.5±14.7 ms, read: 145.6±54.1 MB/s, size: 108.2 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /NFS/celine/aicup/yoloNew/labels.cache... 16863 images, 14076 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 16863/16863 13.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1054/1054 20.8it/s 50.7s<0.0s
#                    all      16863       2787      0.973      0.975      0.992      0.828
# Speed: 0.3ms preprocess, 2.1ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /NFS/celine/aicup/yoloNew/runs/detect/runs/detect/val
# 0.9919576681218653
# ...
